# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
#
# -----

# %%
#Of the 1163 active players, the vast majority are male (84%). 
#There also exists, a smaller, but notable proportion of female players (14%).
#Our peak age demographic falls between 20-24 (44.8%) 
#with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
import pandas as pd
import numpy as np

player_count = [{"total_players": 1163}]
players = pd.DataFrame(player_count)
players
# Out:
#    total_players
# 0           1163

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#MEAN & SUM
price_mean = purchase_data["Price"].mean()
print(price_mean)

price_sum = purchase_data["Price"].sum()
print(price_sum)

age_mean = purchase_data["Age"].mean()
print(age_mean)


#UNIQUE ITEMS
age_unique = purchase_data["Age"].unique()
print(age_unique)

gender_unique = purchase_data["Gender"].unique()
print(gender_unique)

IN_unique = purchase_data["Item Name"].unique()
print(IN_unique)

price_unique = purchase_data["Price"].unique()
print(price_unique)
# Out:
# 3.0509871794871795
# 2379.77
# 22.714102564102564
# [20 40 24 23 22 36 35 21 30 38 29 11  7 19 37 10  8 18 27 33 32 25 12 34
#  17 15 13 26 16 28 31 39 44 41  9 14 42 43 45]
# ['Male' 'Other / Non-Disclosed' 'Female']
# ['Extraction, Quickblade Of Trembling Hands' 'Frenzied Scimitar'
#  'Final Critic' 'Blindscythe' 'Fury' 'Dreamkiss'
#  'Interrogator, Blood Blade of the Queen' 'Abyssal Shard' 'Souleater'
#  'Ghastly Adamantite Protector' 'Singed Onyx Warscythe'
#  'Renewed Skeletal Katana' "Bloodlord's Fetish"
#  'Bone Crushing Silver Skewer' 'Deadline, Voice Of Subtlety'
#  'Second Chance' 'Devine' 'Nirvana' 'Blazefury, Protector of Delusions'
#  'Despair, Favor of Due Diligence' 'Sun Strike, Jaws of Twisted Visions'
#  'Warped Fetish' 'Severance' 'Persuasion'
#  'Oathbreaker, Last Hope of the Breaking Storm' 'Demise'
#  'Blood-Forged Skeletal Spine' 'Stormbringer, Dark Blade of Ending Misery'
#  'Shadow Strike, Glory of Ending Hope' 'Striker'
# ...

# %%
#print(age_unique[38])

unique_items_count = purchase_data.nunique()
unique_items_count
# Out:
# 45
# Purchase ID    780
# SN             576
# Age             39
# Gender           3
# Item ID        183
# Item Name      179
# Price          145
# dtype: int64

# %%
count_of_purchases = len(purchase_data.index)
print(count_of_purchases)


PurchaseID_nunique = purchase_data['Purchase ID'].nunique()
SN_nunique = purchase_data['SN'].nunique()
Age_nunique = purchase_data['Age'].nunique()
Gender_nunique = purchase_data['Gender'].nunique()
ItemID_nunique = purchase_data['Item ID'].nunique()
ItemName_nunique = purchase_data['Item Name'].nunique()
Price_nunique = purchase_data['Price'].nunique()
# Out:
# 780

# %%
summary_list = {"Row Name": ["Purchase ID", "SN", "Age", "Gender", "Item ID", "Item Name", "Price"],
                "Number of Unique Items": [PurchaseID_nunique, SN_nunique, Age_nunique, Gender_nunique, ItemID_nunique, ItemName_nunique, Price_nunique], 
                "Average": ["N/A","N/A",age_mean,"N/A","N/A","N/A",price_mean], 
                "Number of Purchases": [count_of_purchases, "N/A", "N/A","N/A","N/A","N/A","N/A"], 
                "Total Revenue": ["N/A","N/A","N/A","N/A","N/A","N/A",price_sum]}  

summary_df = pd.DataFrame(summary_list)
summary_df
# Out:
#       Row Name  Number of Unique Items    Average Number of Purchases  \
# 0  Purchase ID                     780        N/A                 780
# 1           SN                     576        N/A                 N/A
# 2          Age                      39  22.714103                 N/A
# 3       Gender                       3        N/A                 N/A
# 4      Item ID                     183        N/A                 N/A
# 5    Item Name                     179        N/A                 N/A
# 6        Price                     145   3.050987                 N/A
#
#   Total Revenue
# 0           N/A
# 1           N/A
# 2           N/A
# 3           N/A
# 4           N/A
# 5           N/A
# 6       2379.77

# %%
# Out:
#    Number of Unique Items Average Price Number of Purchases Total Revenue
# 0                     183         $3.05                 780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
gender_unique = purchase_data["Gender"].unique()
print(gender_unique)

print(purchase_data["Gender"].value_counts())
# Out:
# ['Male' 'Other / Non-Disclosed' 'Female']
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
#Each value in the df represents the total purchases a gender made
gender_df = pd.DataFrame(purchase_data["Gender"].value_counts())
print(gender_df)

#total number of unique customers
SN_nunique_count = purchase_data['SN'].nunique()
print(SN_nunique_count)
#Names of all unique customers
SN_unique_customers = purchase_data['SN'].unique()
print(SN_unique_customers)
# Out:
#                        Gender
# Male                      652
# Female                    113
# Other / Non-Disclosed      15
# 576
# ['Lisim78' 'Lisovynya38' 'Ithergue48' 'Chamassasya86' 'Iskosia90'
#  'Yalae81' 'Itheria73' 'Iskjaskst81' 'Undjask33' 'Chanosian48' 'Inguron55'
#  'Haisrisuir60' 'Saelaephos52' 'Assjaskan73' 'Saesrideu94' 'Lisassa64'
#  'Lisirra25' 'Zontibe81' 'Reunasu60' 'Chamalo71' 'Iathenudil29'
#  'Phiarithdeu40' 'Siarithria38' 'Eyrian71' 'Siala43' 'Lisirra87'
#  'Lirtossa84' 'Eusri44' 'Aela59' 'Tyida79' 'Idai61' 'Farusrian86'
#  'Aeralria27' 'Haillyrgue51' 'Sondim73' 'Jeyciman68' 'Idaisuir85'
#  'Seuthep89' 'Reulae52' 'Sondilsaya62' 'Aerithriaphos45' 'Assosia88'
#  'Aidaillodeu39' 'Aelly27' 'Tyeosri53' 'Haerith37' 'Yasrisu92'
#  'Chanuchi25' 'Asur96' 'Iaralrgue74' 'Chanosia34' 'Aelin32' 'Ilosianya35'
#  'Zhisrisu83' 'Phaelap26' 'Raesty92' 'Palyon91' 'Tyisur83' 'Yaliru88'
#  'Yadanu52' 'Jiskimya77' 'Yadaphos40' 'Alo38' 'Phaena87' 'Chamirraya83'
# ...

# %%
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
SN_unique_customers_df = pd.DataFrame(SN_unique_customers, columns =['SN'])


Purchase_ID_col = purchase_data["Purchase ID"]

SN_unique_customers_df['Purchase ID'] = Purchase_ID_col
SN_unique_customers_df
# Out:
#                 SN  Purchase ID
# 0          Lisim78            0
# 1      Lisovynya38            1
# 2       Ithergue48            2
# 3    Chamassasya86            3
# 4        Iskosia90            4
# ..             ...          ...
# 571         Hala31          571
# 572     Jiskjask80          572
# 573     Aethedru70          573
# 574     Yathecal72          574
# 575        Sisur91          575
#
# [576 rows x 2 columns]

# %%
gender_col = purchase_data["Gender"]
gender_df2 = pd.DataFrame(gender_col)

gender_df2['Purchase ID'] = Purchase_ID_col
gender_df2
# Out:
#      Gender  Purchase ID
# 0      Male            0
# 1      Male            1
# 2      Male            2
# 3      Male            3
# 4      Male            4
# ..      ...          ...
# 775  Female          775
# 776    Male          776
# 777    Male          777
# 778    Male          778
# 779    Male          779
#
# [780 rows x 2 columns]

# %%
inner_merge_df = pd.merge(SN_unique_customers_df, gender_df2, on="Purchase ID")
inner_merge_df
# Out:
#                 SN  Purchase ID  Gender
# 0          Lisim78            0    Male
# 1      Lisovynya38            1    Male
# 2       Ithergue48            2    Male
# 3    Chamassasya86            3    Male
# 4        Iskosia90            4    Male
# ..             ...          ...     ...
# 571         Hala31          571    Male
# 572     Jiskjask80          572  Female
# 573     Aethedru70          573    Male
# 574     Yathecal72          574    Male
# 575        Sisur91          575    Male
#
# [576 rows x 3 columns]

# %%
print(inner_merge_df["Gender"].value_counts())
# Out:
# Male                     476
# Female                    88
# Other / Non-Disclosed     12
# Name: Gender, dtype: int64

# %%
#gender_df.iloc[0:1, 0:1]

# %%
a = (gender_df['Gender'] / gender_df['Gender'].sum()) * 100

print(a)
# Out:
# Male                     83.589744
# Female                   14.487179
# Other / Non-Disclosed     1.923077
# Name: Gender, dtype: float64

# %%
#percent_gender= pd.DataFrame(gender_df['percent'])
#print(percent_gender)

# %%
#inner_merge_df = pd.merge(gender_df, percent_gender, on="percent")
#inner_merge_df

# %%
#percent_dict = {"percent": [83.589744, 14.487179, 1.923077]}
#percent_df = pd.DataFrame(percent_dict)
#percent_df

# %%
percent = [83.589744, 14.487179, 1.923077]
gender_df['Percent'] = percent

gender_df
# Out:
#                        Gender    Percent
# Male                      652  83.589744
# Female                    113  14.487179
# Other / Non-Disclosed      15   1.923077

# %%
# Out:
#                        Total Count  Percentage of Players
# Male                           484                  84.03
# Female                          81                  14.06
# Other / Non-Disclosed           11                   1.91

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Just to keep as reference
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#purchase count:
    #scroll up to see

#Total Number of people who made purchases
    #SN_nunique_count = purchase_data['SN'].nunique()
    #print(SN_nunique_count)

#SNs of everyone who made purchases
    #SN_unique_items = purchase_data["SN"].unique()
    #print(SN_unique_items)

# %%
#AVG purchase price per gender
    #we know how many times each gender occurs
#Total purchase value per gender

#AVG total purchase per person per gender

# %%
# Out:
#                       Purchase Count Average Purchase Price  \
# Gender
# Female                           113                  $3.20
# Male                             652                  $3.02
# Other / Non-Disclosed             15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                             $1,967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
#I used the information below to categorize the occurances into the bins
#age_count = (purchase_data["Age"].value_counts())
#age_count_df = pd.DataFrame(age_count)

#age_count_df.columns =['Occurances']

#age_count_df
# Out:
#        Total Count  Percentage of Players
# <10             17                   2.95
# 10-14           22                   3.82
# 15-19          107                  18.58
# 20-24          258                  44.79
# 25-29           77                  13.37
# 30-34           52                   9.03
# 35-39           31                   5.38
# 40+             12                   2.08

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Out:
#       Purchase Count Average Purchase Price Total Purchase Value  \
# 10-14             28                  $2.96               $82.78
# 15-19            136                  $3.04              $412.89
# 20-24            365                  $3.05            $1,114.06
# 25-29            101                  $2.90              $293.00
# 30-34             73                  $2.93              $214.00
# 35-39             41                  $3.60              $147.67
# 40+               13                  $2.94               $38.24
# <10               23                  $3.35               $77.13
#
#       Avg Total Purchase per Person
# 10-14                         $3.76
# 15-19                         $3.86
# 20-24                         $4.32
# 25-29                         $3.81
# 30-34                         $4.12
# 35-39                         $4.76
# 40+                           $3.19
# <10                           $4.54

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#print indices of the top spenders. The amount of indices tells you the purchase count 
#HELP NOTE: IS THERE AN EASIER WAY?
#print(purchase_data[purchase_data['SN']=='Lisosia93'].index.values) #5
#print(purchase_data[purchase_data['SN']=='Idastidru52'].index.values) #4
#print(purchase_data[purchase_data['SN']=='Chamjask73'].index.values) #3
#print(purchase_data[purchase_data['SN']=='Iral74'].index.values) #4
#print(purchase_data[purchase_data['SN']=='Iskadarya95'].index.values) #3



Lisosia = avg_purchase_price_SN['Lisosia93']
print(Lisosia)
Idastidru = avg_purchase_price_SN['Idastidru52']
print(Idastidru)
Chamjask = avg_purchase_price_SN['Chamjask73']
print(Chamjask)
Iral = avg_purchase_price_SN['Iral74']
print(Iral)
Iskadarya = avg_purchase_price_SN['Iskadarya95']
print(Iskadarya)



Lisosia_Total = Lisosia * 5 
print(Lisosia_Total)

Idastidru_Total = Idastidru * 4
print(Idastidru_Total)

Chamjask_Total = Chamjask * 3
print(Chamjask_Total)

Iral_Total = Iral * 4
print(Iral_Total)

Iskadarya_Total = Iskadarya * 3
print(Iskadarya_Total)


#HELP NOTE: I tried to pass the lists into the dict and I created the dataframe but it did returned a list
#in the rows. Is there an easier way to create the dataframe without having to put each individual value 
#in the dict?

top_spenders_count = [5,4,3,4,3]

top_spenders_price = [3.79, 3.86, 4.61, 3.40, 4.37]

top_spenders_purchase_total = [18.96, 15.45, 13.83, 13.62, 13.10]
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 145     Fiery Glass Crusader                                      9
# 108     Extraction, Quickblade Of Trembling Hands                 9
# 82      Nirvana                                                   9
# 19      Pursuit, Cudgel of Necromancy                             8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
# 82      Nirvana                                           $4.90
# 19      Pursuit, Cudgel of Necromancy                     $1.02
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 92      Final Critic                                              8
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 92      Final Critic                                      $4.88
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...
